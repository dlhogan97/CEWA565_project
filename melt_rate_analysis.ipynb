# %%
import pandas as pd
import numpy as np
import os
import datetime as dt
import scipy.stats as stats
from scipy.interpolate import interp1d
import datetime as dt
import sys
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from SNOTEL_splitter import splitFireSNOTEL

import seaborn as sns
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIGGER_SIZE = 14

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# fire locations
fire_sites = {'Sentinel Butte':'Gold Axe Camp', # apparent postive/null
              'Grouse Camp':'Trough', # apparent negative
              'Harts Pass':'Lyman Lake', # apparent positive/null
              'Three Creeks Meadow': 'Salt Creek Falls', # apparent negative/null
              'Pope Ridge': 'Blewett Pass'}# apparent negative/null
filepath = r'C:\Users\dlhogan\OneDrive - UW\Documents\GitHub\CEWA565_project\data\fire_sites'
disruption_dates = pd.read_excel(os.path.join(filepath,'snotel_fire_data_new.xlsx'))
variable = 'depth'

# %%
def getSites(site, paired, fire_dict=fire_sites, filepath=filepath, disruption_dates=disruption_dates, variable=variable,postyrs=5):
    """getSites will return filtered dataframes for the inputed site and its paired site, and can filter 
       to particular number of years after the disturbance

    Args:
        site (str): site of interest
        paired (str): paired site
        fire_dict (dict): dict containing sites and paired sites. Defaults to fire_sites.
        filepath (str): Path to data location. Defaults to filepath.
        disruption_dates (df): df containing fire start date and intensity values. Defaults to disruption_dates.
        variable (str): swe or depth. Can be adapted set of variables of interest. Defaults to swe.
        postyrs (int, optional): number of years after distrubance to report data. Defaults to 5.

    Returns:
        [type]: [description]
    """
    melt=False
    if variable == 'meltdates':
        variable = 'swe_meltdates'
        melt = True
    df_b, df_a = splitFireSNOTEL(site,fire_sites,variable,disruption_dates,filepath)
    df_paired_b, df_paired_a = splitFireSNOTEL(paired,fire_sites,variable,disruption_dates,filepath)
    print(df_paired_a)
    if melt is False:
        fire_year = min(df_a.index.year)
        if postyrs != 'max':
            df_a = df_a.loc[dt.date(fire_year,10,1):dt.date(fire_year+postyrs,9,30)]
            df_paired_a = df_paired_a.loc[dt.date(fire_year,10,1):dt.date(fire_year+postyrs,9,30)]
        # remove 2015 as exceptionally dry year
        for df in [df_b,df_a,df_paired_a,df_paired_b]:
            df = df[df.index.year != 2015]
            df = df.dropna()
            print(df)
        if len(df_paired_b) > len(df_b):
            min_date = min(df_b.index)
            df_paired_b = df_paired_b.loc[df_paired_b.index > min_date]
        elif len(df_b) > len(df_paired_b):
            min_date = min(df_paired_b.index)
            df_b = df_b.loc[df_b.index > min_date]
    else:
        if postyrs != 'max':
            df_a = df_a[df_a['water_year'] < (min(df_a['water_year']+postyrs))]
            df_paired_a = df_paired_a[df_paired_a['water_year'] < (min(df_paired_a['water_year']+postyrs))]
        # remove 2015 as exceptionally dry year
        
        if len(df_paired_b) > len(df_b):
            min_date = min(df_b['water_year'])
            df_paired_b = df_paired_b.loc[df_paired_b['water_year'] > min_date]
        elif len(df_b) > len(df_paired_b):
            min_date = min(df_paired_b['water_year'])
            df_b = df_b.loc[df_b['water_year'] > min_date]
        for df in [df_b,df_a,df_paired_a,df_paired_b]:
            df = df[df['water_year']!= 2015].set_index('water_year')
    print('Filtering to {} years after fire...'.format(postyrs))
    print('Done!')
    return df_b, df_a, df_paired_b, df_paired_a

# %%
def max_swe(df):
    df = df.dropna()
    max_swe = df.loc[df.groupby('water_year')['SNOTEL:SNWD_D'].idxmax()].reset_index().set_index('water_year')#df[(df.index.month==4) & (df.index.day==1)].reset_index().set_index('water_year')
    dowy = []
    for date in max_swe['datetime']:
        dowy.append(date2DOWY(date))
    max_swe['dowy_max'] = dowy
    max_swe = max_swe[['dowy_max','SNOTEL:SNWD_D']]
    max_swe = max_swe[max_swe['dowy_max'].between(122,250)]
    return max_swe

# %%
def date2DOWY(day_of_interest):
    day_of_interest = day_of_interest.date()
    dowy_start = dt.date(day_of_interest.year-1,10,1)
    dowy = day_of_interest - dowy_start
    return dowy.days

# %%
diff_in_diff_results = {}
for i,(site,paired) in enumerate(fire_sites.items()):
    if site =='Harts Pass':
        continue
    df_b, df_a, df_paired_b, df_paired_a = getSites(site,paired, variable='depth',postyrs=5)
    for df in [df_b, df_a, df_paired_b, df_paired_a]:
        df['water_year'] = df.index.year
    df_b_max = max_swe(df_b)
    df_a_max = max_swe(df_a) 
    df_paired_b_max = max_swe(df_paired_b) 
    df_paired_a_max = max_swe(df_paired_a) 
    
    df_b_melt, df_a_melt, df_paired_b_melt, df_paired_a_melt = getSites(site,paired, variable='meltdates',postyrs=5)
    
        
    df_join = df_b_max.join(df_b_melt.set_index('water_year',drop=False))
    df_join['melt_rate'] = df_join['SNOTEL:SNWD_D']/(df_join['DOWY']-df_join['dowy_max'])
    df1 = df_join
    df1 = df1[['water_year','melt_rate']].dropna()
    df1['pre_post'] = 0
    df1['original'] = 1

    df_join = df_paired_b_max.join(df_paired_b_melt.set_index('water_year',drop=False))
    df_join['melt_rate'] = df_join['SNOTEL:SNWD_D']/(df_join['DOWY']-df_join['dowy_max'])
    df2 = df_join
    df2 = df2[['water_year','melt_rate']].dropna()
    df2['pre_post'] = 0
    df2['original'] = 0

    df_join = df_a_max.join(df_a_melt.set_index('water_year',drop=False))
    df_join['melt_rate'] = df_join['SNOTEL:SNWD_D']/(df_join['DOWY']-df_join['dowy_max'])
    df3 = df_join
    df3 = df3[['water_year','melt_rate']].dropna()
    df3['pre_post'] = 1
    df3['original'] = 1

    df_join = df_paired_a_max.join(df_paired_a_melt.set_index('water_year',drop=False))
    df_join['melt_rate'] = df_join['SNOTEL:SNWD_D']/(df_join['DOWY']-df_join['dowy_max'])
    df4 = df_join
    df4 = df4[['water_year','melt_rate']].dropna()
    df4['pre_post'] = 1
    df4['original'] = 0

    df = pd.concat([df1,df2,df3,df4])

    results = smf.ols("melt_rate ~ original*pre_post",data=df).fit()
    print(results.summary())
    # if i == 2:
    #     sm.graphics.plot_partregress(results, 'original:pre_post')
    results_as_html = results.summary().tables[1].as_html()

    diff_in_diff_ols = pd.read_html(results_as_html,header=0, index_col=0)[0]
    diff_in_diff_ols.to_excel('data/meltrate/'+site+'_diff_in_diff_rate.xlsx')
    diff_in_diff_results[site] = [diff_in_diff_ols,results]
    post_fire_difference = diff_in_diff_ols.loc['original:pre_post']['coef']
    post_fire_stderror = diff_in_diff_ols.loc['original:pre_post']['std err']

    print('Post fire influence on melt rate at {}: {} cm/day'.format(site,post_fire_difference))
    print('Post fire influence on melt rate + standard error: {} cm/day'.format(post_fire_difference+post_fire_stderror))
    print('Post fire influence on melt rate - standard error: {} cm/day'.format(post_fire_difference-post_fire_stderror))
# Out:
# Sentinel Butte for depth
# 4365
# Sentinel Butte for depth
# 1775
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2015-08-11            0.0          V          nc  2015-08-11T00:00:00
# 2015-08-12            0.0          V          nc  2015-08-12T00:00:00
# 2015-08-13            0.0          V          nc  2015-08-13T00:00:00
# 2015-08-14            0.0          V          nc  2015-08-14T00:00:00
# 2015-08-15            0.0          V          nc  2015-08-15T00:00:00
# ...                   ...        ...         ...                  ...
# 2021-11-13            2.0          V          nc  2021-11-13T00:00:00
# 2021-11-14            2.0          E          nc  2021-11-14T00:00:00
# 2021-11-15            2.0          V          nc  2021-11-15T00:00:00
# 2021-11-16            0.0          E          nc  2021-11-16T00:00:00
# 2021-11-17            0.0          E          nc  2021-11-17T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2015-08-11          0            0            1                           1
# 2015-08-12          0            0            1                           1
# 2015-08-13          0            0            1                           1
# 2015-08-14          0            0            1                           1
# 2015-08-15          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2021-11-13          0            0            1                           1
# 2021-11-14          0            0            1                           1
# 2021-11-15          0            0            1                           1
# 2021-11-16          0            0            1                           1
# 2021-11-17          0            0            1                           1
#
# [2287 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2003-08-29              0          E          nc  2003-08-29T00:00:00
# 2003-08-30              0          V          nc  2003-08-30T00:00:00
# 2003-08-31              0          E          nc  2003-08-31T00:00:00
# 2003-09-01              0          E          nc  2003-09-01T00:00:00
# 2003-09-02              0          E          nc  2003-09-02T00:00:00
# ...                   ...        ...         ...                  ...
# 2014-12-27              9          V          nc  2014-12-27T00:00:00
# 2014-12-28             12          V          nc  2014-12-28T00:00:00
# 2014-12-29             14          V          nc  2014-12-29T00:00:00
# 2014-12-30             14          V          nc  2014-12-30T00:00:00
# 2014-12-31             13          V          nc  2014-12-31T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2003-08-29          0            0            1                           1
# 2003-08-30          0            0            1                           1
# 2003-08-31          0            0            1                           1
# 2003-09-01          0            0            1                           1
# 2003-09-02          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2014-12-27          0            0            1                           1
# 2014-12-28          0            0            1                           1
# 2014-12-29          0            0            1                           1
# 2014-12-30          0            0            1                           1
# 2014-12-31          0            0            1                           1
#
# [4143 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2016-01-01             23          V          nc  2016-01-01T00:00:00
# 2016-01-02             23          V          nc  2016-01-02T00:00:00
# 2016-01-03             22          V          nc  2016-01-03T00:00:00
# 2016-01-04             23          V          nc  2016-01-04T00:00:00
# 2016-01-05             27          V          nc  2016-01-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2020-09-26              0          V          nc  2020-09-26T00:00:00
# 2020-09-27              0          V          nc  2020-09-27T00:00:00
# 2020-09-28              0          V          nc  2020-09-28T00:00:00
# 2020-09-29              0          V          nc  2020-09-29T00:00:00
# 2020-09-30              0          V          nc  2020-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2016-01-01          0            0            1                           1
# 2016-01-02          0            0            1                           1
# 2016-01-03          0            0            1                           1
# 2016-01-04          0            0            1                           1
# 2016-01-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2020-09-26          0            0            1                           1
# 2020-09-27          0            0            1                           1
# 2020-09-28          0            0            1                           1
# 2020-09-29          0            0            1                           1
# 2020-09-30          0            0            1                           1
#
# [1735 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2016-01-01           25.0          E          nc  2016-01-01T00:00:00
# 2016-01-02           25.0          V          nc  2016-01-02T00:00:00
# 2016-01-03           25.0          V          nc  2016-01-03T00:00:00
# 2016-01-04           26.0          E          nc  2016-01-04T00:00:00
# 2016-01-05           29.0          V          nc  2016-01-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2020-09-26            0.0          E          nc  2020-09-26T00:00:00
# 2020-09-27            0.0          E          nc  2020-09-27T00:00:00
# 2020-09-28            0.0          E          nc  2020-09-28T00:00:00
# 2020-09-29            0.0          E          nc  2020-09-29T00:00:00
# 2020-09-30            0.0          E          nc  2020-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2016-01-01          0            0            1                           1
# 2016-01-02          0            0            1                           1
# 2016-01-03          0            0            1                           1
# 2016-01-04          0            0            1                           1
# 2016-01-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2020-09-26          0            0            1                           1
# 2020-09-27          0            0            1                           1
# 2020-09-28          0            0            1                           1
# 2020-09-29          0            0            1                           1
# 2020-09-30          0            0            1                           1
#
# [1735 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2010-10-01            0.0          E          nc  2010-10-01T00:00:00
# 2010-10-02            0.0          E          nc  2010-10-02T00:00:00
# 2010-10-03            0.0          E          nc  2010-10-03T00:00:00
# 2010-10-04            0.0          E          nc  2010-10-04T00:00:00
# 2010-10-05            0.0          E          nc  2010-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2014-12-27            9.0          V          nc  2014-12-27T00:00:00
# 2014-12-28           10.0          E          nc  2014-12-28T00:00:00
# 2014-12-29           12.0          V          nc  2014-12-29T00:00:00
# 2014-12-30           11.0          V          nc  2014-12-30T00:00:00
# 2014-12-31           11.0          V          nc  2014-12-31T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2010-10-01          0            0            1                           1
# 2010-10-02          0            0            1                           1
# 2010-10-03          0            0            1                           1
# 2010-10-04          0            0            1                           1
# 2010-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2014-12-27          0            0            1                           1
# 2014-12-28          0            0            1                           1
# 2014-12-29          0            0            1                           1
# 2014-12-30          0            0            1                           1
# 2014-12-31          0            0            1                           1
#
# [1553 rows x 8 columns]
# Filtering to 5 years after fire...
# Done!
# Sentinel Butte for swe_meltdates
# Sentinel Butte for swe_meltdates
#     water_year   last_snow  DOWY
# 5         2016  2016-04-21   203
# 6         2017  2017-05-17   228
# 7         2018  2018-05-09   220
# 8         2019  2019-04-25   206
# 9         2020  2020-05-07   219
# 10        2021  2021-05-03   214
# Filtering to 5 years after fire...
# Done!
# C:\Users\dlhogan\miniconda3\envs\downgrade\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# C:\Users\dlhogan\miniconda3\envs\downgrade\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              melt_rate   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.8996
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):              0.470
# Time:                        12:13:18   Log-Likelihood:               0.018321
# No. Observations:                  16   AIC:                             7.963
# Df Residuals:                      12   BIC:                             11.05
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.8194      0.161      5.086      0.000       0.468       1.171
# original             -0.1069      0.213     -0.501      0.625      -0.571       0.358
# pre_post             -0.2498      0.213     -1.172      0.264      -0.714       0.215
# original:pre_post     0.3975      0.284      1.401      0.187      -0.221       1.016
# ==============================================================================
# Omnibus:                        0.062   Durbin-Watson:                   2.688
# Prob(Omnibus):                  0.969   Jarque-Bera (JB):                0.224
# Skew:                           0.119   Prob(JB):                        0.894
# Kurtosis:                       2.472   Cond. No.                         7.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Post fire influence on melt rate at Sentinel Butte: 0.3975 cm/day
# Post fire influence on melt rate + standard error: 0.6815 cm/day
# Post fire influence on melt rate - standard error: 0.11350000000000005 cm/day
# Grouse Camp for depth
# 3341
# Grouse Camp for depth
# 3952
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-09-08            0.0          V          nc  2012-09-08T00:00:00
# 2012-09-09            0.0          E          nc  2012-09-09T00:00:00
# 2012-09-10            0.0          V          nc  2012-09-10T00:00:00
# 2012-09-11            0.0          V          nc  2012-09-11T00:00:00
# 2012-09-12            0.0          V          nc  2012-09-12T00:00:00
# ...                   ...        ...         ...                  ...
# 2021-11-02            0.0          V          nc  2021-11-02T00:00:00
# 2021-11-03            0.0          V          nc  2021-11-03T00:00:00
# 2021-11-04            0.0          V          nc  2021-11-04T00:00:00
# 2021-11-05            0.0          V          nc  2021-11-05T00:00:00
# 2021-11-06            0.0          V          nc  2021-11-06T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-09-08          0            0            1                           1
# 2012-09-09          0            0            1                           1
# 2012-09-10          0            0            1                           1
# 2012-09-11          0            0            1                           1
# 2012-09-12          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2021-11-02          0            0            1                           1
# 2021-11-03          0            0            1                           1
# 2021-11-04          0            0            1                           1
# 2021-11-05          0            0            1                           1
# 2021-11-06          0            0            1                           1
#
# [3347 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2003-07-17            0.0          E          nc  2003-07-17T00:00:00
# 2003-07-18            0.0          E          nc  2003-07-18T00:00:00
# 2003-07-19            0.0          E          nc  2003-07-19T00:00:00
# 2003-07-20            0.0          E          nc  2003-07-20T00:00:00
# 2003-07-21            0.0          E          nc  2003-07-21T00:00:00
# ...                   ...        ...         ...                  ...
# 2012-09-03            0.0          V          nc  2012-09-03T00:00:00
# 2012-09-04            0.0          V          nc  2012-09-04T00:00:00
# 2012-09-05            0.0          V          nc  2012-09-05T00:00:00
# 2012-09-06            0.0          V          nc  2012-09-06T00:00:00
# 2012-09-07            0.0          V          nc  2012-09-07T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2003-07-17          0            0            1                           1
# 2003-07-18          0            0            1                           1
# 2003-07-19          0            0            1                           1
# 2003-07-20          0            0            1                           1
# 2003-07-21          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2012-09-03          0            0            1                           1
# 2012-09-04          0            0            1                           1
# 2012-09-05          0            0            1                           1
# 2012-09-06          0            0            1                           1
# 2012-09-07          0            0            1                           1
#
# [3341 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-10-01            0.0          E          nc  2012-10-01T00:00:00
# 2012-10-02            0.0          E          nc  2012-10-02T00:00:00
# 2012-10-03            0.0          E          nc  2012-10-03T00:00:00
# 2012-10-04            0.0          E          nc  2012-10-04T00:00:00
# 2012-10-05            0.0          E          nc  2012-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2017-09-26            0.0          V          nc  2017-09-26T00:00:00
# 2017-09-27            0.0          V          nc  2017-09-27T00:00:00
# 2017-09-28            0.0          V          nc  2017-09-28T00:00:00
# 2017-09-29            0.0          V          nc  2017-09-29T00:00:00
# 2017-09-30            0.0          E          nc  2017-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-10-01          0            0            1                           1
# 2012-10-02          0            0            1                           1
# 2012-10-03          0            0            1                           1
# 2012-10-04          0            0            1                           1
# 2012-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2017-09-26          0            0            1                           1
# 2017-09-27          0            0            1                           1
# 2017-09-28          0            0            1                           1
# 2017-09-29          0            0            1                           1
# 2017-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-10-01            0.0          E          nc  2012-10-01T00:00:00
# 2012-10-02            0.0          E          nc  2012-10-02T00:00:00
# 2012-10-03            0.0          V          nc  2012-10-03T00:00:00
# 2012-10-04            0.0          E          nc  2012-10-04T00:00:00
# 2012-10-05            0.0          V          nc  2012-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2017-09-26            0.0          E          nc  2017-09-26T00:00:00
# 2017-09-27            0.0          E          nc  2017-09-27T00:00:00
# 2017-09-28            0.0          E          nc  2017-09-28T00:00:00
# 2017-09-29            0.0          E          nc  2017-09-29T00:00:00
# 2017-09-30            0.0          E          nc  2017-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-10-01          0            0            1                           1
# 2012-10-02          0            0            1                           1
# 2012-10-03          0            0            1                           1
# 2012-10-04          0            0            1                           1
# 2012-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2017-09-26          0            0            1                           1
# 2017-09-27          0            0            1                           1
# 2017-09-28          0            0            1                           1
# 2017-09-29          0            0            1                           1
# 2017-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2001-07-28            0.0          V          nc  2001-07-28T00:00:00
# 2001-10-30            2.0          E          nc  2001-10-30T00:00:00
# 2001-10-31            2.0          E          nc  2001-10-31T00:00:00
# 2001-11-01            2.0          E          nc  2001-11-01T00:00:00
# 2001-11-02            3.0          E          nc  2001-11-02T00:00:00
# ...                   ...        ...         ...                  ...
# 2012-09-03            0.0          V          nc  2012-09-03T00:00:00
# 2012-09-04            0.0          E          nc  2012-09-04T00:00:00
# 2012-09-05            0.0          E          nc  2012-09-05T00:00:00
# 2012-09-06            0.0          V          nc  2012-09-06T00:00:00
# 2012-09-07            0.0          V          nc  2012-09-07T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2001-07-28          0            0            1                           1
# 2001-10-30          0            0            1                           1
# 2001-10-31          0            0            1                           1
# 2001-11-01          0            0            1                           1
# 2001-11-02          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2012-09-03          0            0            1                           1
# 2012-09-04          0            0            1                           1
# 2012-09-05          0            0            1                           1
# 2012-09-06          0            0            1                           1
# 2012-09-07          0            0            1                           1
#
# [3952 rows x 8 columns]
# Filtering to 5 years after fire...
# Done!
# Grouse Camp for swe_meltdates
# Grouse Camp for swe_meltdates
#     water_year   last_snow  DOWY
# 34        2013  2013-05-25   236
# 35        2014  2014-05-04   215
# 36        2015  2015-04-15   196
# 37        2016  2016-04-30   212
# 38        2017  2017-05-21   232
# 39        2018  2018-05-08   219
# 40        2019  2019-05-10   221
# 41        2020  2020-04-30   212
# 42        2021  2021-05-03   214
# Filtering to 5 years after fire...
# Done!
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              melt_rate   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     1.345
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):              0.295
# Time:                        12:13:19   Log-Likelihood:                -2.4699
# No. Observations:                  20   AIC:                             12.94
# Df Residuals:                      16   BIC:                             16.92
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.8073      0.116      6.978      0.000       0.562       1.053
# original              0.1224      0.158      0.773      0.451      -0.213       0.458
# pre_post             -0.2884      0.245     -1.175      0.257      -0.809       0.232
# original:pre_post     0.3889      0.321      1.211      0.244      -0.292       1.070
# ==============================================================================
# Omnibus:                       10.636   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                8.024
# Skew:                           1.327   Prob(JB):                       0.0181
# Kurtosis:                       4.608   Cond. No.                         7.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Post fire influence on melt rate at Grouse Camp: 0.3889 cm/day
# Post fire influence on melt rate + standard error: 0.7099 cm/day
# Post fire influence on melt rate - standard error: 0.06790000000000002 cm/day
# Three Creeks Meadow for depth
# 2200
# Three Creeks Meadow for depth
# 2512
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-09-09            0.0          V          nc  2012-09-09T00:00:00
# 2012-09-10            0.0          V          nc  2012-09-10T00:00:00
# 2012-09-11            0.0          V          nc  2012-09-11T00:00:00
# 2012-09-12            0.0          V          nc  2012-09-12T00:00:00
# 2012-09-13            0.0          V          nc  2012-09-13T00:00:00
# ...                   ...        ...         ...                  ...
# 2021-11-13            0.0          V          nc  2021-11-13T00:00:00
# 2021-11-14            0.0          V          nc  2021-11-14T00:00:00
# 2021-11-15            0.0          V          nc  2021-11-15T00:00:00
# 2021-11-16            0.0          V          nc  2021-11-16T00:00:00
# 2021-11-17            0.0          V          nc  2021-11-17T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-09-09          0            0            1                           1
# 2012-09-10          0            0            1                           1
# 2012-09-11          0            0            1                           1
# 2012-09-12          0            0            1                           1
# 2012-09-13          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2021-11-13          0            0            1                           1
# 2021-11-14          0            0            1                           1
# 2021-11-15          0            0            1                           1
# 2021-11-16          0            0            1                           1
# 2021-11-17          0            0            1                           1
#
# [3357 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2006-09-01            0.0          E          nc  2006-09-01T00:00:00
# 2006-09-02            0.0          E          nc  2006-09-02T00:00:00
# 2006-09-03            0.0          E          nc  2006-09-03T00:00:00
# 2006-09-04            0.0          E          nc  2006-09-04T00:00:00
# 2006-09-05            0.0          E          nc  2006-09-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2012-09-04            0.0          E          nc  2012-09-04T00:00:00
# 2012-09-05            0.0          E          nc  2012-09-05T00:00:00
# 2012-09-06            0.0          E          nc  2012-09-06T00:00:00
# 2012-09-07            0.0          E          nc  2012-09-07T00:00:00
# 2012-09-08            0.0          E          nc  2012-09-08T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2006-09-01          0            0            1                           1
# 2006-09-02          0            0            1                           1
# 2006-09-03          0            0            1                           1
# 2006-09-04          0            0            1                           1
# 2006-09-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2012-09-04          0            0            1                           1
# 2012-09-05          0            0            1                           1
# 2012-09-06          0            0            1                           1
# 2012-09-07          0            0            1                           1
# 2012-09-08          0            0            1                           1
#
# [2200 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-10-01            0.0          V          nc  2012-10-01T00:00:00
# 2012-10-02            0.0          V          nc  2012-10-02T00:00:00
# 2012-10-03            0.0          V          nc  2012-10-03T00:00:00
# 2012-10-04            0.0          V          nc  2012-10-04T00:00:00
# 2012-10-05            0.0          V          nc  2012-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2017-09-26            0.0          E          nc  2017-09-26T00:00:00
# 2017-09-27            0.0          E          nc  2017-09-27T00:00:00
# 2017-09-28            0.0          E          nc  2017-09-28T00:00:00
# 2017-09-29            0.0          E          nc  2017-09-29T00:00:00
# 2017-09-30            0.0          E          nc  2017-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-10-01          0            0            1                           1
# 2012-10-02          0            0            1                           1
# 2012-10-03          0            0            1                           1
# 2012-10-04          0            0            1                           1
# 2012-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2017-09-26          0            0            1                           1
# 2017-09-27          0            0            1                           1
# 2017-09-28          0            0            1                           1
# 2017-09-29          0            0            1                           1
# 2017-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2012-10-01            0.0          V          nc  2012-10-01T00:00:00
# 2012-10-02            0.0          V          nc  2012-10-02T00:00:00
# 2012-10-03            0.0          V          nc  2012-10-03T00:00:00
# 2012-10-04            0.0          V          nc  2012-10-04T00:00:00
# 2012-10-05            0.0          V          nc  2012-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2017-09-26            0.0          E          nc  2017-09-26T00:00:00
# 2017-09-27            0.0          E          nc  2017-09-27T00:00:00
# 2017-09-28            0.0          E          nc  2017-09-28T00:00:00
# 2017-09-29            0.0          E          nc  2017-09-29T00:00:00
# 2017-09-30            0.0          E          nc  2017-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2012-10-01          0            0            1                           1
# 2012-10-02          0            0            1                           1
# 2012-10-03          0            0            1                           1
# 2012-10-04          0            0            1                           1
# 2012-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2017-09-26          0            0            1                           1
# 2017-09-27          0            0            1                           1
# 2017-09-28          0            0            1                           1
# 2017-09-29          0            0            1                           1
# 2017-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2005-08-30            0.0          E          nc  2005-08-30T00:00:00
# 2005-08-31            0.0          E          nc  2005-08-31T00:00:00
# 2005-09-01            0.0          E          nc  2005-09-01T00:00:00
# 2005-09-02            0.0          E          nc  2005-09-02T00:00:00
# 2005-09-03            0.0          E          nc  2005-09-03T00:00:00
# ...                   ...        ...         ...                  ...
# 2012-09-04            0.0          V          nc  2012-09-04T00:00:00
# 2012-09-05            0.0          V          nc  2012-09-05T00:00:00
# 2012-09-06            0.0          V          nc  2012-09-06T00:00:00
# 2012-09-07            0.0          V          nc  2012-09-07T00:00:00
# 2012-09-08            0.0          V          nc  2012-09-08T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2005-08-30          0            0            1                           1
# 2005-08-31          0            0            1                           1
# 2005-09-01          0            0            1                           1
# 2005-09-02          0            0            1                           1
# 2005-09-03          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2012-09-04          0            0            1                           1
# 2012-09-05          0            0            1                           1
# 2012-09-06          0            0            1                           1
# 2012-09-07          0            0            1                           1
# 2012-09-08          0            0            1                           1
#
# [2512 rows x 8 columns]
# Filtering to 5 years after fire...
# Done!
# Three Creeks Meadow for swe_meltdates
# Three Creeks Meadow for swe_meltdates
#     water_year   last_snow  DOWY
# 32        2013  2013-05-23   234
# 33        2014  2014-05-02   213
# 34        2015  2015-04-17   198
# 35        2016  2016-05-05   217
# 36        2017  2017-05-25   236
# 37        2018  2018-05-05   216
# 38        2019  2019-05-12   223
# 39        2020  2020-05-13   225
# 40        2021  2021-05-23   234
# Filtering to 5 years after fire...
# Done!
# C:\Users\dlhogan\miniconda3\envs\downgrade\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# C:\Users\dlhogan\miniconda3\envs\downgrade\lib\site-packages\scipy\stats\stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              melt_rate   R-squared:                       0.320
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     2.353
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):              0.113
# Time:                        12:13:19   Log-Likelihood:                -2.8829
# No. Observations:                  19   AIC:                             13.77
# Df Residuals:                      15   BIC:                             17.54
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.2411      0.142      8.756      0.000       0.939       1.543
# original             -0.2552      0.192     -1.330      0.203      -0.664       0.154
# pre_post             -0.5621      0.213     -2.644      0.018      -1.015      -0.109
# original:pre_post     0.5188      0.295      1.758      0.099      -0.110       1.148
# ==============================================================================
# Omnibus:                        1.031   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.875
# Skew:                           0.282   Prob(JB):                        0.646
# Kurtosis:                       2.113   Cond. No.                         6.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Post fire influence on melt rate at Three Creeks Meadow: 0.5188 cm/day
# Post fire influence on melt rate + standard error: 0.8138000000000001 cm/day
# Post fire influence on melt rate - standard error: 0.22380000000000005 cm/day
# Pope Ridge for depth
# 5969
# Pope Ridge for depth
# 5467
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2014-07-16              0          E          nc  2014-07-16T00:00:00
# 2014-07-17              0          E          nc  2014-07-17T00:00:00
# 2014-07-18              0          E          nc  2014-07-18T00:00:00
# 2014-07-19              0          V          nc  2014-07-19T00:00:00
# 2014-07-20              0          V          nc  2014-07-20T00:00:00
# ...                   ...        ...         ...                  ...
# 2021-11-13              2          V          nc  2021-11-13T00:00:00
# 2021-11-14              2          V          nc  2021-11-14T00:00:00
# 2021-11-15              0          V          nc  2021-11-15T00:00:00
# 2021-11-16              0          V          nc  2021-11-16T00:00:00
# 2021-11-17              0          V          nc  2021-11-17T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2014-07-16          0            0            1                           1
# 2014-07-17          0            0            1                           1
# 2014-07-18          0            0            1                           1
# 2014-07-19          0            0            1                           1
# 2014-07-20          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2021-11-13          0            0            1                           1
# 2021-11-14          0            0            1                           1
# 2021-11-15          0            0            1                           1
# 2021-11-16          0            0            1                           1
# 2021-11-17          0            0            1                           1
#
# [2682 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 1997-10-30            0.0          V          nc  1997-10-30T00:00:00
# 1997-10-31            0.0          V          nc  1997-10-31T00:00:00
# 1997-11-01            0.0          V          nc  1997-11-01T00:00:00
# 1997-11-02            0.0          V          nc  1997-11-02T00:00:00
# 1997-11-03            0.0          V          nc  1997-11-03T00:00:00
# ...                   ...        ...         ...                  ...
# 2014-07-11            0.0          E          nc  2014-07-11T00:00:00
# 2014-07-12            0.0          E          nc  2014-07-12T00:00:00
# 2014-07-13            0.0          E          nc  2014-07-13T00:00:00
# 2014-07-14            0.0          E          nc  2014-07-14T00:00:00
# 2014-07-15            0.0          E          nc  2014-07-15T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 1997-10-30          0            0            1                           1
# 1997-10-31          0            0            1                           1
# 1997-11-01          0            0            1                           1
# 1997-11-02          0            0            1                           1
# 1997-11-03          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2014-07-11          0            0            1                           1
# 2014-07-12          0            0            1                           1
# 2014-07-13          0            0            1                           1
# 2014-07-14          0            0            1                           1
# 2014-07-15          0            0            1                           1
#
# [5969 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2014-10-01            0.0          V          nc  2014-10-01T00:00:00
# 2014-10-02            0.0          E          nc  2014-10-02T00:00:00
# 2014-10-03            0.0          V          nc  2014-10-03T00:00:00
# 2014-10-04            0.0          V          nc  2014-10-04T00:00:00
# 2014-10-05            0.0          V          nc  2014-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2019-09-26            0.0          E          nc  2019-09-26T00:00:00
# 2019-09-27            0.0          E          nc  2019-09-27T00:00:00
# 2019-09-28            0.0          E          nc  2019-09-28T00:00:00
# 2019-09-29            0.0          E          nc  2019-09-29T00:00:00
# 2019-09-30            0.0          E          nc  2019-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2014-10-01          0            0            1                           1
# 2014-10-02          0            0            1                           1
# 2014-10-03          0            0            1                           1
# 2014-10-04          0            0            1                           1
# 2014-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2019-09-26          0            0            1                           1
# 2019-09-27          0            0            1                           1
# 2019-09-28          0            0            1                           1
# 2019-09-29          0            0            1                           1
# 2019-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2014-10-01              0          E          nc  2014-10-01T00:00:00
# 2014-10-02              0          V          nc  2014-10-02T00:00:00
# 2014-10-03              0          E          nc  2014-10-03T00:00:00
# 2014-10-04              0          E          nc  2014-10-04T00:00:00
# 2014-10-05              0          E          nc  2014-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2019-09-26              0          E          nc  2019-09-26T00:00:00
# 2019-09-27              0          E          nc  2019-09-27T00:00:00
# 2019-09-28              0          E          nc  2019-09-28T00:00:00
# 2019-09-29              0          E          nc  2019-09-29T00:00:00
# 2019-09-30              3          V          nc  2019-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2014-10-01          0            0            1                           1
# 2014-10-02          0            0            1                           1
# 2014-10-03          0            0            1                           1
# 2014-10-04          0            0            1                           1
# 2014-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2019-09-26          0            0            1                           1
# 2019-09-27          0            0            1                           1
# 2019-09-28          0            0            1                           1
# 2019-09-29          0            0            1                           1
# 2019-09-30          0            0            1                           1
#
# [1461 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 1999-07-28              0          E          nc  1999-07-28T00:00:00
# 1999-07-29              0          E          nc  1999-07-29T00:00:00
# 1999-07-30              0          E          nc  1999-07-30T00:00:00
# 1999-07-31              0          E          nc  1999-07-31T00:00:00
# 1999-08-01              0          E          nc  1999-08-01T00:00:00
# ...                   ...        ...         ...                  ...
# 2014-07-11              0          E          nc  2014-07-11T00:00:00
# 2014-07-12              0          E          nc  2014-07-12T00:00:00
# 2014-07-13              0          E          nc  2014-07-13T00:00:00
# 2014-07-14              0          E          nc  2014-07-14T00:00:00
# 2014-07-15              0          E          nc  2014-07-15T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 1999-07-28          0            0            1                           1
# 1999-07-29          0            0            1                           1
# 1999-07-30          0            0            1                           1
# 1999-07-31          0            0            1                           1
# 1999-08-01          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2014-07-11          0            0            1                           1
# 2014-07-12          0            0            1                           1
# 2014-07-13          0            0            1                           1
# 2014-07-14          0            0            1                           1
# 2014-07-15          0            0            1                           1
#
# [5467 rows x 8 columns]
# Filtering to 5 years after fire...
# Done!
# Pope Ridge for swe_meltdates
# Pope Ridge for swe_meltdates
#     water_year   last_snow  DOWY
# 33        2015  2015-03-11   161
# 34        2016  2016-04-13   195
# 35        2017  2017-05-05   216
# 36        2018  2018-04-26   207
# 37        2019  2019-04-23   204
# 38        2020  2020-06-24   267
# 39        2021  2021-04-21   202
# Filtering to 5 years after fire...
# Done!
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              melt_rate   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.128
# Method:                 Least Squares   F-statistic:                   0.09383
# Date:                Wed, 01 Dec 2021   Prob (F-statistic):              0.963
# Time:                        12:13:19   Log-Likelihood:                 2.7533
# No. Observations:                  25   AIC:                             2.493
# Df Residuals:                      21   BIC:                             7.369
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.8822      0.068     12.924      0.000       0.740       1.024
# original             -0.0181      0.104     -0.174      0.864      -0.235       0.199
# pre_post             -0.0016      0.181     -0.009      0.993      -0.377       0.374
# original:pre_post     0.0996      0.258      0.385      0.704      -0.438       0.637
# ==============================================================================
# Omnibus:                        1.298   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.523   Jarque-Bera (JB):                1.003
# Skew:                           0.229   Prob(JB):                        0.606
# Kurtosis:                       2.132   Cond. No.                         7.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Post fire influence on melt rate at Pope Ridge: 0.0996 cm/day
# Post fire influence on melt rate + standard error: 0.35760000000000003 cm/day
# Post fire influence on melt rate - standard error: -0.1584 cm/day

# %%
df_join = df_a_max.join(df_a_melt.set_index('water_year'))
df_join['melt_rate'] = df_join['DOWY']-df_join['dowy_max']

# %%
df_b_melt, df_a_melt, df_paired_b_melt, df_paired_a_melt = getSites('Harts Pass','Lyman Lake', variable='depth',postyrs=5)
# Out:
# Harts Pass for depth
# 1079
# Harts Pass for depth
# 0
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2005-09-15            0.0          E          nc  2005-09-15T00:00:00
# 2005-09-16            0.0          E          nc  2005-09-16T00:00:00
# 2005-09-17            0.0          E          nc  2005-09-17T00:00:00
# 2005-09-18            0.0          E          nc  2005-09-18T00:00:00
# 2005-09-19            0.0          E          nc  2005-09-19T00:00:00
# ...                   ...        ...         ...                  ...
# 2021-10-22            0.0          E          nc  2021-10-22T00:00:00
# 2021-10-25            4.0          E          nc  2021-10-25T00:00:00
# 2021-11-01           11.0          E          nc  2021-11-01T00:00:00
# 2021-11-08           23.0          E          nc  2021-11-08T00:00:00
# 2021-11-14           46.0          E          nc  2021-11-14T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2005-09-15          0            0            1                           1
# 2005-09-16          0            0            1                           1
# 2005-09-17          0            0            1                           1
# 2005-09-18          0            0            1                           1
# 2005-09-19          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2021-10-22          0            0            1                           1
# 2021-10-25          0            0            1                           1
# 2021-11-01          0            0            1                           1
# 2021-11-08          0            0            1                           1
# 2021-11-14          0            0            1                           1
#
# [5708 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2000-05-04           64.0          V          nc  2000-05-04T00:00:00
# 2000-05-05           63.0          V          nc  2000-05-05T00:00:00
# 2000-05-06           64.0          V          nc  2000-05-06T00:00:00
# 2000-05-07           65.0          V          nc  2000-05-07T00:00:00
# 2000-05-08           63.0          V          nc  2000-05-08T00:00:00
# ...                   ...        ...         ...                  ...
# 2003-07-31            0.0          E          nc  2003-07-31T00:00:00
# 2003-08-01            0.0          E          nc  2003-08-01T00:00:00
# 2003-08-02            0.0          E          nc  2003-08-02T00:00:00
# 2003-08-03            0.0          E          nc  2003-08-03T00:00:00
# 2003-08-04            0.0          E          nc  2003-08-04T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2000-05-04          0            0            1                           1
# 2000-05-05          0            0            1                           1
# 2000-05-06          0            0            1                           1
# 2000-05-07          0            0            1                           1
# 2000-05-08          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2003-07-31          0            0            1                           1
# 2003-08-01          0            0            1                           1
# 2003-08-02          0            0            1                           1
# 2003-08-03          0            0            1                           1
# 2003-08-04          0            0            1                           1
#
# [1079 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2003-10-01            0.0          E          nc  2003-10-01T00:00:00
# 2003-10-02            0.0          E          nc  2003-10-02T00:00:00
# 2003-10-03            0.0          E          nc  2003-10-03T00:00:00
# 2003-10-04            0.0          E          nc  2003-10-04T00:00:00
# 2003-10-05            0.0          V          nc  2003-10-05T00:00:00
# ...                   ...        ...         ...                  ...
# 2008-09-26            0.0          E          nc  2008-09-26T00:00:00
# 2008-09-27            0.0          E          nc  2008-09-27T00:00:00
# 2008-09-28            0.0          E          nc  2008-09-28T00:00:00
# 2008-09-29            0.0          E          nc  2008-09-29T00:00:00
# 2008-09-30            0.0          E          nc  2008-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2003-10-01          0            0            1                           1
# 2003-10-02          0            0            1                           1
# 2003-10-03          0            0            1                           1
# 2003-10-04          0            0            1                           1
# 2003-10-05          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2008-09-26          0            0            1                           1
# 2008-09-27          0            0            1                           1
# 2008-09-28          0            0            1                           1
# 2008-09-29          0            0            1                           1
# 2008-09-30          0            0            1                           1
#
# [1744 rows x 8 columns]
#             SNOTEL:SNWD_D qualifiers censor_code        date_time_utc  \
# datetime
# 2005-09-15            0.0          E          nc  2005-09-15T00:00:00
# 2005-09-16            0.0          E          nc  2005-09-16T00:00:00
# 2005-09-17            0.0          E          nc  2005-09-17T00:00:00
# 2005-09-18            0.0          E          nc  2005-09-18T00:00:00
# 2005-09-19            0.0          E          nc  2005-09-19T00:00:00
# ...                   ...        ...         ...                  ...
# 2008-09-26            0.0          E          nc  2008-09-26T00:00:00
# 2008-09-27            0.0          E          nc  2008-09-27T00:00:00
# 2008-09-28            0.0          E          nc  2008-09-28T00:00:00
# 2008-09-29            0.0          E          nc  2008-09-29T00:00:00
# 2008-09-30            0.0          E          nc  2008-09-30T00:00:00
#
#             method_id  method_code  source_code  quality_control_level_code
# datetime
# 2005-09-15          0            0            1                           1
# 2005-09-16          0            0            1                           1
# 2005-09-17          0            0            1                           1
# 2005-09-18          0            0            1                           1
# 2005-09-19          0            0            1                           1
# ...               ...          ...          ...                         ...
# 2008-09-26          0            0            1                           1
# 2008-09-27          0            0            1                           1
# 2008-09-28          0            0            1                           1
# 2008-09-29          0            0            1                           1
# 2008-09-30          0            0            1                           1
#
# [1070 rows x 8 columns]
# Empty DataFrame
# Columns: [SNOTEL:SNWD_D, qualifiers, censor_code, date_time_utc, method_id, method_code, source_code, quality_control_level_code]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15884/258229419.py in <module>
# ----> 1 df_b_melt, df_a_melt, df_paired_b_melt, df_paired_a_melt = getSites('Harts Pass','Lyman Lake', variable='depth',postyrs=5)
#
# ~\AppData\Local\Temp/ipykernel_15884/1207434761.py in getSites(site, paired, fire_dict, filepath, disruption_dates, variable, postyrs)
#      36             df_paired_b = df_paired_b.loc[df_paired_b.index > min_date]
#      37         elif len(df_b) > len(df_paired_b):
# ---> 38             min_date = min(df_paired_b.index)
#      39             df_b = df_b.loc[df_b.index > min_date]
#      40     else:
#
# ValueError: min() arg is an empty sequence
